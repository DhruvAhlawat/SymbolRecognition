# %%
import keras.datasets.mnist as mnist;
import keras;
from sklearn.metrics import classification_report; 
import numpy as np; 

data = mnist;

(x_train,y_train), (x_test,y_test) = data.load_data(); 
model = keras.Sequential([
    # Input Layers
    keras.layers.Flatten(input_shape=(28, 28, )),
	# Hidden Layers
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dropout(0.5),
    # Output Layers
    keras.layers.Dense(10, activation='softmax')
])

# Compile model
model.compile(
    optimizer = keras.optimizers.Adam(),
    loss = keras.losses.SparseCategoricalCrossentropy(),
    metrics = ['accuracy']
)

# Model training
model.fit(x_train, y_train, verbose=1, epochs=50, batch_size=32)

# Make prediction from test data
prediction_probability = model.predict(x_test)
prediction = np.array([np.argmax(pred) for pred in prediction_probability])

# Display the model performance
print(classification_report(y_test, prediction)); 

# Save model
model.save('mnist_classification.h5')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 3s 0us/step
# Epoch 1/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.7613 - accuracy: 0.8328
# Epoch 2/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2619 - accuracy: 0.9340
# Epoch 3/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2094 - accuracy: 0.9477
# Epoch 4/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1820 - accuracy: 0.9546
# Epoch 5/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1527 - accuracy: 0.9611
# Epoch 6/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1381 - accuracy: 0.9672
# Epoch 7/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1275 - accuracy: 0.9694
# Epoch 8/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1207 - accuracy: 0.9708
# Epoch 9/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1013 - accuracy: 0.9755
# Epoch 10/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0991 - accuracy: 0.9760
# Epoch 11/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1065 - accuracy: 0.9758
# Epoch 12/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0915 - accuracy: 0.9787
# Epoch 13/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0896 - accuracy: 0.9799
# Epoch 14/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0858 - accuracy: 0.9796
# Epoch 15/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0832 - accuracy: 0.9807
# Epoch 16/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0791 - accuracy: 0.9824
# Epoch 17/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0790 - accuracy: 0.9825
# Epoch 18/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0914 - accuracy: 0.9818
# Epoch 19/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0712 - accuracy: 0.9840
# Epoch 20/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0624 - accuracy: 0.9854
# Epoch 21/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0794 - accuracy: 0.9827
# Epoch 22/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0632 - accuracy: 0.9855
# Epoch 23/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0664 - accuracy: 0.9853
# Epoch 24/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0703 - accuracy: 0.9849
# Epoch 25/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0703 - accuracy: 0.9847
# Epoch 26/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0616 - accuracy: 0.9868
# Epoch 27/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0759 - accuracy: 0.9843
# Epoch 28/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0620 - accuracy: 0.9864
# Epoch 29/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0685 - accuracy: 0.9857
# Epoch 30/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0613 - accuracy: 0.9866
# Epoch 31/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0675 - accuracy: 0.9851
# Epoch 32/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0635 - accuracy: 0.9876
# Epoch 33/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0768 - accuracy: 0.9845
# Epoch 34/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0780 - accuracy: 0.9841
# Epoch 35/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0572 - accuracy: 0.9880
# Epoch 36/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0707 - accuracy: 0.9852
# Epoch 37/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0717 - accuracy: 0.9860
# Epoch 38/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.0708 - accuracy: 0.9873
# Epoch 39/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0616 - accuracy: 0.9878
# Epoch 40/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0622 - accuracy: 0.9867
# Epoch 41/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0707 - accuracy: 0.9877
# Epoch 42/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0886 - accuracy: 0.9856
# Epoch 43/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1152 - accuracy: 0.9842
# Epoch 44/50
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0687 - accuracy: 0.9880
# Epoch 45/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0623 - accuracy: 0.9890
# Epoch 46/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0684 - accuracy: 0.9856
# Epoch 47/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0678 - accuracy: 0.9849
# Epoch 48/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0712 - accuracy: 0.9859
# Epoch 49/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0541 - accuracy: 0.9885
# Epoch 50/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0633 - accuracy: 0.9872
# 313/313 [==============================] - 0s 818us/step
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       980
#            1       0.98      0.99      0.99      1135
#            2       0.98      0.98      0.98      1032
#            3       0.97      0.96      0.97      1010
#            4       0.98      0.98      0.98       982
#            5       0.99      0.95      0.97       892
#            6       0.99      0.98      0.98       958
#            7       0.99      0.97      0.98      1028
#            8       0.97      0.97      0.97       974
#            9       0.91      0.98      0.95      1009
#
#     accuracy                           0.97     10000
#    macro avg       0.98      0.97      0.97     10000
# weighted avg       0.98      0.97      0.97     10000

# %%
finalModel = keras.models.load_model('mnist_classification.h5')
